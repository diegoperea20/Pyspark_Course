# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 281.4/281.4 MB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.7/199.7 KB 20.5 MB/s eta 0:00:00
# ...
#   Created wheel for pyspark: filename=pyspark-3.3.2-py2.py3-none-any.whl size=281824025 sha256=1768725f225f386c7df15b3e147ec6f9e3400c6c9ed0f918d4544c43d210b6d4
#   Stored in directory: /root/.cache/pip/wheels/b1/59/a0/a1a0624b5e865fd389919c1a10f53aec9b12195d6747710baf
# Successfully built pyspark
# ...

# %%
import pyspark

# %%
import pandas as pd
pd.read_csv('/content/drive/MyDrive/Pypask_Course/test1.csv')
# Out:
#    name;age
# 0  name1;30
# 1  name2;30
# 2  name3;30

# %%
pd.read_csv('/content/drive/MyDrive/Pypask_Course/test2.csv')
# Out:
#    name;age
# 0  name1;30
# 1  name2;30
# 2  name3;30

# %%
pd.read_csv('/content/drive/MyDrive/Pypask_Course/test3.csv')
# Out:
#    name;age
# 0  name1;30
# 1  name2;30
# 2  name3;30

# %%
pd.read_excel('/content/drive/MyDrive/Pypask_Course/test4.xlsx')
# Out:
#     name  age
# 0  name1   30
# 1  name2   30
# 2  name3   30

# %%
from pyspark.sql import SparkSession

# %%
spark=SparkSession.builder.appName('Practise').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://2ecbc2db0fb0:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practise</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark=spark.read.csv('/content/drive/MyDrive/Pypask_Course/test1.csv')

# %%
df_pyspark.show()
# Out:
# +--------+
# |     _c0|
# +--------+
# |name;age|
# |name1;30|
# |name2;30|
# |name3;30|
# +--------+

# %%
df_pyspark=spark.read.option('header','true').csv('/content/drive/MyDrive/Pypask_Course/test1.csv')

# %%
type(df_pyspark)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df_pyspark.head(3)
# Out:
# [Row(name;age='name1;30'), Row(name;age='name2;30'), Row(name;age='name3;30')]

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- name;age: string (nullable = true)

# %% [markdown]
# #Ahora con tres columnas
